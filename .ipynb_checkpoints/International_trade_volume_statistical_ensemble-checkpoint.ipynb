# %% [markdown]
# **Title : Time series forecasting with statistical ensemble model: an application for global international trade volume prediction**

# %% [markdown]
# # Model

# %% [markdown]
# The statistical ensemble model we used here is SCUM (SCUM simple combination of univariate models).
# SCUM is s a median combination of the point
# forecasts and prediction intervals of four models, namely exponential smoothing, complex exponential smoothing, automatic autoregressive integrated moving average and
# dynamic optimised theta.

# %% [markdown]
# ![Screenshot 2024-01-18 105722.png](data:image/png;base64,...)

# %% [markdown]
# *Source :  Petropoulos & Svetunkov, 2020*

# %% [markdown]
# This approach was used in the M4-competition and performed very well, being ranked 6th for the point forecasts and prediction intervals, and 2nd and 3rd for the point forecasts of the weekly and quarterly data respectively (Petropoulos & Svetunkov, 2020).

# %% [markdown]
# * ETS is based on time series decomposition,
# * ARIMA captures inter-dependencies in time series,
# * CES focuses on non-linear long-term tendencies in
# time series,
# * and DOTM employs short-term curvatures and long-term trends.
#
# Thus, each model captures something that the others cannot (Petropoulos & Svetunkov, 2020).

# %% [markdown]
# # Install packages

# %%
pip install statsforecast

# %% [markdown]
# # Import librairies

# %%
import os
import time
import re

from functools import partial
from multiprocessing import cpu_count

import numpy as np
import pandas as pd
from math import sqrt
import matplotlib.pyplot as plt

from statsforecast import StatsForecast
from statsforecast.models import (
        AutoTheta, AutoETS, AutoCES,AutoARIMA,
        Theta, OptimizedTheta,
        DynamicTheta, DynamicOptimizedTheta
)

from sklearn.metrics import mean_absolute_error, mean_squared_error

from datetime import timedelta

# %% [markdown]
# # Data

# %% [markdown]
# The data is from multisources such as World Bank and FMI and combined manually in one excel file.

# %% [markdown]
# ## Load data

# %%
#Import form default drive storage
Y_df = pd.read_excel("/content/data.xlsx")
Y_df["Unnamed: 0"] = pd.to_datetime(Y_df["Unnamed: 0"], format="%YM%m")
Y_df.rename(columns={"Unnamed: 0":"date"},inplace=True)


# function to rename columns names
def ren_col(col_name):
    # replace not accepted characters by underscores
    cleaned_col_name = re.sub('[^a-zA-Z0-9_]', '_', col_name)
    return cleaned_col_name

# Apply the rename column function
Y_df.columns = [ren_col(colum) for colum in Y_df.columns]
Y_df
# Out:
#           date    world_expo    world_impo  Crude_oil__average____bbl_  \
# 0   1960-01-01  4.460728e+03  4.414615e+03                    1.630000
# 1   1960-02-01  1.077233e+04  1.179932e+04                    1.630000
# 2   1960-03-01  8.879228e+03  9.483650e+03                    1.630000
# 3   1960-04-01  8.207328e+03  8.777070e+03                    1.630000
# 4   1960-05-01  8.477928e+03  8.971800e+03                    1.630000
# ..         ...           ...           ...                         ...
# 751 2022-08-01  2.047739e+06  2.152595e+06                   95.973333
# 752 2022-09-01  2.096082e+06  2.147257e+06                   88.220000
# 753 2022-10-01  1.993195e+06  2.063197e+06                   90.326667
# 754 2022-11-01  2.027231e+06  2.087345e+06                   87.376667
# 755 2022-12-01  1.992570e+06  2.042125e+06                   78.066667
#
#      Crude_oil__Brent___bbl_  Crude_oil__Dubai___bbl_  Crude_oil__WTI___bbl_  \
# ...

# %% [markdown]
# ## Choice of the variable of interest

# %%
plt.plot(Y_df['date'], Y_df["world_expo"],linestyle='dotted', color='b',label = "Export")
plt.plot(Y_df['date'], Y_df["world_impo"],linestyle='dotted', color='r',label = "Import")

plt.legend()

plt.show()

# %% [markdown]
# Exportation and importation are very similar, so we can choose one as well as the other. For our application, let's assume that exportations is our trade volume metrics.

# %% [markdown]
# ## Preparing data for the prediction

# %%
Y_df = Y_df[['date', 'world_expo']]
Y_df.rename(columns={"date":"ds","world_expo":"y"},inplace=True)
Y_df["unique_id"] = "export"
Y_df
# Out:
# <ipython-input-27-25ec3d207232>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y_df.rename(columns={"date":"ds","world_expo":"y"},inplace=True)
# <ipython-input-27-25ec3d207232>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y_df["unique_id"] = "export"
#             ds             y unique_id
# 0   1960-01-01  4.460728e+03    export
# 1   1960-02-01  1.077233e+04    export
# 2   1960-03-01  8.879228e+03    export
# 3   1960-04-01  8.207328e+03    export
# 4   1960-05-01  8.477928e+03    export
# ..         ...           ...       ...
# ...

# %% [markdown]
# Let's initiaize temporal variables :

# %%
frequency = "M" # we have a monthly data
seasonality = 12 # we excpected an annual seasonality
horizon = 12 # we would like to forecast the next 12 months trade volume (next 1 year)

# %% [markdown]
# Let's create our test set :

# %%
test = Y_df.groupby('unique_id').tail(horizon)
test
# Out:
#             ds             y unique_id
# 744 2022-01-01  1.911738e+06    export
# 745 2022-02-01  1.839300e+06    export
# 746 2022-03-01  2.171946e+06    export
# 747 2022-04-01  2.012690e+06    export
# 748 2022-05-01  2.099545e+06    export
# 749 2022-06-01  2.172644e+06    export
# 750 2022-07-01  2.067300e+06    export
# 751 2022-08-01  2.047739e+06    export
# 752 2022-09-01  2.096082e+06    export
# 753 2022-10-01  1.993195e+06    export
# 754 2022-11-01  2.027231e+06    export
# 755 2022-12-01  1.992570e+06    export

# %%
train = Y_df.drop(test.index)
train
# Out:
#             ds             y unique_id
# 0   1960-01-01  4.460728e+03    export
# 1   1960-02-01  1.077233e+04    export
# 2   1960-03-01  8.879228e+03    export
# 3   1960-04-01  8.207328e+03    export
# 4   1960-05-01  8.477928e+03    export
# ..         ...           ...       ...
# 739 2021-08-01  1.796607e+06    export
# 740 2021-09-01  1.919034e+06    export
# 741 2021-10-01  1.962658e+06    export
# 742 2021-11-01  2.037553e+06    export
# 743 2021-12-01  2.062236e+06    export
#
# [744 rows x 3 columns]

# %% [markdown]
# # Exploratory data analysis

# %%
Y_df.describe()
# Out:
#                   y
# count  7.560000e+02
# mean   5.512778e+05
# std    5.960761e+05
# min    4.460728e+03
# 25%    5.664640e+04
# 50%    2.871899e+05
# 75%    1.033335e+06
# max    2.172644e+06

# %% [markdown]
# We may need to analyze seasonality and stationarity even if we have already go forward with the automatic optimal parameters.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Build the model & prediction

# %% [markdown]
# Let's initialize each statistics models :

# %%
models = [
        AutoETS(season_length=seasonality),
        AutoCES(season_length=seasonality),
        AutoARIMA(season_length=seasonality),
        DynamicOptimizedTheta(season_length=seasonality),
    ]

# %% [markdown]
# Run the forecasting :

# %%
fcst = StatsForecast(df=train, models=models, freq=frequency, n_jobs=cpu_count())
forecasts = fcst.forecast(h=horizon)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py:399: FutureWarning: The `df` argument of the StatsForecast constructor as well as reusing stored dfs from other methods is deprecated and will raise an error in a future version. Please provide the `df` argument to the corresponding method instead, e.g. fit/forecast.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py:399: FutureWarning: The `df` argument of the StatsForecast constructor as well as reusing stored dfs from other methods is deprecated and will raise an error in a future version. Please provide the `df` argument to the corresponding method instead, e.g. fit/forecast.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py:417: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
# make date continue
forecasts["ds"] = forecasts["ds"] + timedelta (days=1)
forecasts
# Out:
#                   ds      AutoETS          CES   AutoARIMA  \
# unique_id
# export    2022-01-01  1879947.875  1966826.125  1988510.75
# export    2022-02-01  1777804.375  1921304.000  1970602.25
# export    2022-03-01  2011984.500  2139435.000  2135131.00
# export    2022-04-01  1816950.875  2024578.875  2017999.00
# export    2022-05-01  1854641.750  2052617.500  2030518.75
# export    2022-06-01  2009524.125  2139510.750  2136724.25
# export    2022-07-01  2021975.250  2128097.000  2149643.75
# export    2022-08-01  1945316.000  2077254.750  2110692.50
# export    2022-09-01  2062544.375  2158965.500  2214344.75
# export    2022-10-01  2093481.875  2177506.000  2247740.25
# export    2022-11-01  2101246.500  2174271.500  2290303.50
# export    2022-12-01  2064179.750  2139927.250  2317256.25
#
#            DynamicOptimizedTheta
# unique_id
# export               1767151.250
# export               1816640.250
# export               2038892.375
# export               1935008.875
# ...

# %% [markdown]
# Compute the Statistical Ensemble forecasting :

# %%
forecasts = forecasts.reset_index()
forecasts['StatisticalEnsemble'] = forecasts.set_index(['unique_id', 'ds']).median(axis=1).values
forecasts
# Out:
#    unique_id         ds      AutoETS          CES   AutoARIMA  \
# 0     export 2022-01-01  1879947.875  1966826.125  1988510.75
# 1     export 2022-02-01  1777804.375  1921304.000  1970602.25
# 2     export 2022-03-01  2011984.500  2139435.000  2135131.00
# 3     export 2022-04-01  1816950.875  2024578.875  2017999.00
# 4     export 2022-05-01  1854641.750  2052617.500  2030518.75
# 5     export 2022-06-01  2009524.125  2139510.750  2136724.25
# 6     export 2022-07-01  2021975.250  2128097.000  2149643.75
# 7     export 2022-08-01  1945316.000  2077254.750  2110692.50
# 8     export 2022-09-01  2062544.375  2158965.500  2214344.75
# 9     export 2022-10-01  2093481.875  2177506.000  2247740.25
# 10    export 2022-11-01  2101246.500  2174271.500  2290303.50
# 11    export 2022-12-01  2064179.750  2139927.250  2317256.25
#
#     DynamicOptimizedTheta  StatisticalEnsemble
# 0             1767151.250          1923387.000
# 1             1816640.250          1868972.125
# ...

# %% [markdown]
# ## Evaluation

# %%
y_test = test['y'].values.reshape(-1, horizon)
y_hat = forecasts["StatisticalEnsemble"].values.reshape(-1, horizon)
y_hat_AutoETS = forecasts["AutoETS"].values.reshape(-1, horizon)
y_hat_CES = forecasts["CES"].values.reshape(-1, horizon)
y_hat_AutoARIMA = forecasts["AutoARIMA"].values.reshape(-1, horizon)
y_hat_DynamicOptimizedTheta = forecasts["DynamicOptimizedTheta"].values.reshape(-1, horizon)

# %% [markdown]
# Let's build our metrics (or import it) :

# %%
# Mean Absolute Percentage Error
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Symmetric Mean Absolute Percentage Error
def smape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(2.0 * np.abs(y_true - y_pred) / (np.abs(y_true) + np.abs(y_pred))) * 100

# Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)

# Mean Squared Error (MSE)
def mse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred)

# Root Mean Squared Error (RMSE)
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
import pandas as pd

# create a dictionnary to store the evaluation results
evals = {}
predictions = [y_hat, y_hat_AutoETS, y_hat_CES, y_hat_AutoARIMA, y_hat_DynamicOptimizedTheta]
prediction_names = ['Statistical Ensemble', 'AutoETS', 'CES', 'AutoARIMA', 'DynamicOptimizedTheta']

for i, metric in enumerate((mape, smape, mae, rmse, mse)):
    metric_name = metric.__name__
    for j, y_pred in enumerate(predictions):
        loss = metric(y_test, y_pred)
        evals[f'{metric_name}_{prediction_names[j]}'] = loss

# Create the dataframe
df_evals = pd.DataFrame(evals, index=[0])
df_evals = df_evals.T.reset_index()
df_evals.columns = ['Metric_Prediction', 'Loss']
df_evals[['Metric', 'Prediction']] = df_evals['Metric_Prediction'].str.split('_', expand=True)
df_evals = df_evals.pivot(index='Metric', columns='Prediction', values='Loss')
df_evals
# Out:
# Prediction     AutoARIMA       AutoETS           CES  DynamicOptimizedTheta  \
# Metric
# mae         1.217507e+05  1.070173e+05  7.445476e+04           1.172672e+05
# mape        6.066360e+00  5.194963e+00  3.705468e+00           5.697997e+00
# mse         2.456035e+10  1.580106e+10  8.340429e+09           1.757532e+10
# rmse        1.567174e+05  1.257023e+05  9.132595e+04           1.325720e+05
# smape       5.790849e+00  5.343118e+00  3.612545e+00           5.875463e+00
#
# Prediction  Statistical Ensemble
# Metric
# mae                 6.808923e+04
# mape                3.325017e+00
# mse                 6.964444e+09
# rmse                8.345325e+04
# smape               3.301314e+00

# %% [markdown]
# As we can see, the statistical ensemble has better metrics than the other models that trained it when the latter are used in isolation.

# %% [markdown]
# # Vizualisation

# %%
plt.figure(figsize=(10, 6))
plt.plot(Y_df['ds'].tail(48), Y_df['y'].tail(48),linestyle='-', color='b',label = "Actual")
plt.plot(forecasts['ds'], forecasts['StatisticalEnsemble'],linestyle='-', color='r',label = "Statistical Ensemble")
plt.plot(forecasts['ds'], forecasts['AutoETS'],linestyle='-', color='orange',label = "AutoETS")
plt.plot(forecasts['ds'], forecasts['CES'],linestyle='-', color='y',label = "CES")
plt.plot(forecasts['ds'], forecasts['AutoARIMA'],linestyle='-', color='grey',label = "AutoARIMA")
plt.plot(forecasts['ds'], forecasts['DynamicOptimizedTheta'],linestyle='-', color='g',label = "DynamicOptimizedTheta")

plt.legend()

plt.show()

# %% [markdown]
# The vizualisation confirms our appreciation with the metrics : the Stastical ensemble is the best model.

# %% [markdown]
# # References

# %% [markdown]
# * Petropoulos, F., & Svetunkov, I. (2020). A simple combination of univariate models. International Journal of Forecasting, 36, 110-115.
#
# * Sadler, B., Dey, D., Nguyen, D., & Weeda, T. (2023). A Hybrid Ensemble of Learning Models. SMU Data Science Review, 7(2), Article 1. Récupéré de https://scholar.smu.edu/datasciencereview/vol7/iss2/1
#
# * Makridakis, S., Spiliotis, E., Assimakopoulos, V., Semenoglou, A., Mulder, G., & Nikolopoulos, K. (2023). Statistical, machine learning and deep learning forecasting methods: Comparisons and ways forward. Journal of the Operational Research Society, 74(3), 840-859. https://doi.org/10.1080/01605682.2022.2118629
